# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshyak200-pixel/Bootcamp/blob/main/S2GLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("lakshya")
print("Khandelwal")
# Out:
# lakshya
# Khandelwal
